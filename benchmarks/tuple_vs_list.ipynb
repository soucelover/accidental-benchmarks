# %%
from timing_funcs import run_test

# %%
from typing import Iterable


def create_list(objs: Iterable[object]) -> list[object]:
    return list(objs)


def create_tuple(objs: Iterable[object]) -> list[object]:
    return list(objs)


# We'll construct range object on every run, as to both use generator and
# not exhaust it at very first iteration
run_test("create_list_1", "create_list(range(1))")
run_test("create_tuple_1", "create_tuple(range(1))")

run_test("create_list_1000", "create_list(range(1_000))")
run_test("create_tuple_1000", "create_tuple(range(1_000))")
# Out:
# One loop time for create_list_1: 106.5ns (loop_count=2000000)
# One loop time for create_tuple_1: 103.0ns (loop_count=2000000)
# One loop time for create_list_1000: 8.779μs (loop_count=50000)
# One loop time for create_tuple_1000: 9.562μs (loop_count=50000)
